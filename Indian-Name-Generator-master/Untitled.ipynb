# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image
import pytesseract
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
# Set up nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Syed
# [nltk_data]     Asgar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Syed
# [nltk_data]     Asgar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Syed
# [nltk_data]     Asgar\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Initialize the GUI
root = tk.Tk()
root.withdraw()
# Out:
# ''

# %%
# Ask the user to select an image file
image_path = filedialog.askopenfilename(title="Select an image file",
                                        filetypes=(("Image files", "*.png *.jpg *.jpeg *.gif *.bmp"), ("All files", "*.*")))

# %%
import pytesseract
from PIL import Image
# Import the image
image = Image.open("image.jpg")

# Convert the image to a string
text = pytesseract.image_to_string(image)

# Print the text
print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     254     try:
# --> 255         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     256     except OSError as e:
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419             try:
# -> 1420                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                                          # no special security
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# TesseractNotFoundError                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4140\1613497881.py in <module>
#       5
#       6 # Convert the image to a string
# ----> 7 text = pytesseract.image_to_string(image)
#       8
#       9 # Print the text
#
# ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     421     args = [image, 'txt', lang, config, nice, timeout]
#     422
# --> 423     return {
#     424         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#
# ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py in <lambda>()
#     424         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 426         Output.STRING: lambda: run_and_get_output(*args),
#     427     }[output_type]()
#     428
#
# ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     286         }
#     287
# --> 288         run_tesseract(**kwargs)
#     289         filename = f"{kwargs['output_filename_base']}{extsep}{extension}"
#     290         with open(filename, 'rb') as output_file:
#
# ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     258             raise
#     259         else:
# --> 260             raise TesseractNotFoundError()
#     261
#     262     with timeout_manager(proc, timeout) as error_string:
#
# TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.

# %%
pip install easyocr
# Out:
# Collecting easyocr
#   Using cached easyocr-1.6.2-py3-none-any.whl (2.9 MB)
# Requirement already satisfied: scipy in c:\users\syed asgar\anaconda3\lib\site-packages (from easyocr) (1.9.1)
# Requirement already satisfied: torch in c:\users\syed asgar\anaconda3\lib\site-packages (from easyocr) (2.0.1)
# Collecting Shapely
#   Using cached shapely-2.0.1-cp39-cp39-win_amd64.whl (1.4 MB)
# Collecting pyclipper
#   Using cached pyclipper-1.3.0.post4-cp39-cp39-win_amd64.whl (95 kB)
# Requirement already satisfied: PyYAML in c:\users\syed asgar\anaconda3\lib\site-packages (from easyocr) (6.0)
# Collecting ninja
#   Using cached ninja-1.11.1-py2.py3-none-win_amd64.whl (313 kB)
# Collecting opencv-python-headless<=4.5.4.60
#   Using cached opencv_python_headless-4.5.4.60-cp39-cp39-win_amd64.whl (35.0 MB)
# Requirement already satisfied: Pillow in c:\users\syed asgar\anaconda3\lib\site-packages (from easyocr) (9.2.0)
# Requirement already satisfied: scikit-image in c:\users\syed asgar\anaconda3\lib\site-packages (from easyocr) (0.19.2)
# Requirement already satisfied: numpy in c:\users\syed asgar\anaconda3\lib\site-packages (from easyocr) (1.23.5)
# Collecting python-bidi
#   Using cached python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: torchvision>=0.5 in c:\users\syed asgar\anaconda3\lib\site-packages (from easyocr) (0.15.2)
# Requirement already satisfied: requests in c:\users\syed asgar\anaconda3\lib\site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: jinja2 in c:\users\syed asgar\anaconda3\lib\site-packages (from torch->easyocr) (2.11.3)
# Requirement already satisfied: networkx in c:\users\syed asgar\anaconda3\lib\site-packages (from torch->easyocr) (2.8.4)
# Requirement already satisfied: typing-extensions in c:\users\syed asgar\anaconda3\lib\site-packages (from torch->easyocr) (4.3.0)
# Requirement already satisfied: filelock in c:\users\syed asgar\anaconda3\lib\site-packages (from torch->easyocr) (3.6.0)
# Requirement already satisfied: sympy in c:\users\syed asgar\anaconda3\lib\site-packages (from torch->easyocr) (1.10.1)
# Requirement already satisfied: six in c:\users\syed asgar\anaconda3\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\syed asgar\anaconda3\lib\site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\syed asgar\anaconda3\lib\site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\syed asgar\anaconda3\lib\site-packages (from scikit-image->easyocr) (1.3.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\syed asgar\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.19.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\syed asgar\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (3.0.9)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\syed asgar\anaconda3\lib\site-packages (from jinja2->torch->easyocr) (2.0.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\syed asgar\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\syed asgar\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\syed asgar\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\syed asgar\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.11)
# Requirement already satisfied: mpmath>=0.19 in c:\users\syed asgar\anaconda3\lib\site-packages (from sympy->torch->easyocr) (1.2.1)
# Installing collected packages: pyclipper, ninja, Shapely, python-bidi, opencv-python-headless, easyocr
# Successfully installed Shapely-2.0.1 easyocr-1.6.2 ninja-1.11.1 opencv-python-headless-4.5.4.60 pyclipper-1.3.0.post4 python-bidi-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import easyocr
reader = easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |--------------------------------------------------| 1.7% Complete
# Progress: |█-------------------------------------------------| 3.6% Complete
# Progress: |██------------------------------------------------| 5.0% Complete
# Progress: |███-----------------------------------------------| 6.6% Complete
# Progress: |████----------------------------------------------| 8.1% Complete
# Progress: |████----------------------------------------------| 9.6% Complete
# Progress: |█████---------------------------------------------| 11.2% Complete
# Progress: |██████--------------------------------------------| 12.4% Complete
# Progress: |██████--------------------------------------------| 13.9% Complete
# Progress: |███████-------------------------------------------| 15.9% Complete
# Progress: |████████------------------------------------------| 17.4% Complete
# Progress: |█████████-----------------------------------------| 18.9% Complete
# Progress: |██████████----------------------------------------| 20.4% Complete
# Progress: |██████████----------------------------------------| 21.6% Complete
# Progress: |███████████---------------------------------------| 22.9% Complete
# Progress: |████████████--------------------------------------| 24.8% Complete
# Progress: |█████████████-------------------------------------| 26.4% Complete
# Progress: |█████████████-------------------------------------| 28.0% Complete
# Progress: |██████████████------------------------------------| 29.6% Complete
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |████----------------------------------------------| 8.8% Complete
# Progress: |██████████----------------------------------------| 20.7% Complete
# Progress: |█████████████-------------------------------------| 27.9% Complete
# Progress: |██████████████████--------------------------------| 37.1% Complete
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
def ocr_iteration1(image_path):
    
    result = reader.readtext(image_path)
    for i in range(len(result)):
        print(result[i][1])

# %%
ocr_iteration1('image.jpg')
# Out:
# STATE SCHOLARSHIP PORTAL
# State Scholarship Portal (Post Matric)
# Acknowledgement 2022-23
# Student ID
# 19200381960
# Student Name
# SYED ASGAR AHMED
# Father Name
# Mother
# SYED ASGAR AHMED
# Name
# Date Of Birth
# 11/01/2001
# E-Mail
# syedasgarahmed11@gmail.com
# Mobile Number
# 9342475168
# Taluk of College
# Bengaluru North
